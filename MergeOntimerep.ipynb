# %%
#import pandas module
import pandas as pd
#read the csv file into a dataframe
df = pd.read_csv("C:\\Users\\sachi\\Downloads\\archive (5)\\raw_data\\Ontimerepclean\\ontimerep0119.csv")
df
# Out:
#         Unnamed: 0        DATE  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0           209215  2019-01-01            2                WN   N739GB
# 1           414822  2019-01-01            2                OO   N679SA
# 2           553640  2019-01-01            2                YV   N83329
# 3           201914  2019-01-01            2                AA   N102NN
# 4            31752  2019-01-01            2                AA   N103NN
# ...            ...         ...          ...               ...      ...
# 583980      343879  2019-01-31            4                F9   N205FR
# 583981      343878  2019-01-31            4                F9   N205FR
# 583982      343877  2019-01-31            4                F9   N205FR
# 583983      343883  2019-01-31            4                F9   N206FR
# 583984      515470  2019-01-31            4                WN   N203WN
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ORIGIN_CITY_NAME  \
# ...

# %%
#import the modules
#import os
#import pandas as pd
#read the path
#file_path = "C:\\Users\\sachi\\Downloads\\archive (5)\\raw_data\\Ontimerepclean"
#list all the files from the directory
#file_list = os.listdir(file_path)
#file_list

#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('ontimerep*19.{}'.format('csv'))
csv_files
# Out:
# ['ontimerep0119.csv',
#  'ontimerep0219.csv',
#  'ontimerep0319.csv',
#  'ontimerep0419.csv',
#  'ontimerep0519.csv',
#  'ontimerep0619.csv',
#  'ontimerep0719.csv',
#  'ontimerep0819.csv',
#  'ontimerep0919.csv',
#  'ontimerep1019.csv',
#  'ontimerep1119.csv',
#  'ontimerep1219.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_16848\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_16848\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_16848\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\sachi\AppData\Local\Temp\ipykernel_16848\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_append.to_csv("C:\\Users\\sachi\\Downloads\\archive (5)\\raw_data\\Ontimerepclean\\merged-ontimerep2019.csv")
