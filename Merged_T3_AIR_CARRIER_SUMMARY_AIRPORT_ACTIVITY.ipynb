# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('T3_AIR*.{}'.format('csv'))
csv_files
# Out:
# ['T3_AIR_CARRIER_SUMMARY_AIRPORT_ACTIVITY_2019.csv',
#  'T3_AIR_CARRIER_SUMMARY_AIRPORT_ACTIVITY_2020.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#       OP_UNIQUE_CARRIER                 CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0                   04Q           Tradewind Aviation              15024
# 1                   04Q           Tradewind Aviation              14843
# 2                   04Q           Tradewind Aviation              10257
# 3                   04Q           Tradewind Aviation              15323
# 4                   04Q           Tradewind Aviation              10158
# ...                 ...                          ...                ...
# 33505                ZW  Air Wisconsin Airlines Corp              11721
# 33506                ZW  Air Wisconsin Airlines Corp              10469
# 33507                ZW  Air Wisconsin Airlines Corp              12884
# 33508                ZW  Air Wisconsin Airlines Corp              15380
# 33509                ZW  Air Wisconsin Airlines Corp              15624
#
#       SERVICE_CLASS  REV_ACRFT_DEP_PERF_510  REV_PAX_ENP_110
# ...

# %%
df_concat.to_csv("C:\\Users\\sachi\\Downloads\\archive (5)\\raw_data\\Ontimerepclean\\merged_T3_AIR_CARRIER_SUMMARY_AIRPORT_ACTIVITY.csv")
