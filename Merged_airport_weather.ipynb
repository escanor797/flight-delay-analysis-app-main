# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('airport_weather*.{}'.format('csv'))
csv_files
# Out:
# ['airport_weather_2019.csv', 'airport_weather_2020.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#            STATION                                               NAME  \
# 0      USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 1      USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2      USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 3      USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 4      USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ...            ...                                                ...
# 46221  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46222  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46223  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46224  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46225  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
#
#              DATE   AWND    PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  ...  WT09  \
# ...

# %%
df_concat.to_csv("C:\\Users\\sachi\\Downloads\\archive (5)\\raw_data\\Ontimerepclean\\merged_aiport_weather.csv")
